# %%
from geminiHelper import shortsVideoScript 

script = shortsVideoScript("""
OpenAI’s GPT-5: Blazing Past Boundaries – A Hands-On Review & Use Cases

When OpenAI released GPT-5, the reviewer knew it was time to test how close the world was to truly automated software creation. With early access to the model, they put it through a series of challenges — from building apps and games to conducting deep research — to see what it could really do.

⸻

1. Twitter Clone in Minutes

The first challenge was straightforward:

“Make a Twitter app with a modern black-and-white UI, all buttons functional, and clever icons for profile pictures.”

Within moments, GPT-5 generated a fully functional, interactive front end.
	•	Users could post tweets, browse feeds, check notifications, send DMs, and follow others.
	•	When asked for a backend, it produced a Node.js and Express server, complete with endpoint documentation and deployment instructions.

The process felt less like coding and more like orchestrating a highly skilled, tireless development team.

⸻

2. CRM with Confetti Wins

Next, the model was tasked with creating a business tool:

“Make a CRM for won and lost deals, Kanban style, drag and drop, confetti for wins.”

The result was a sleek, interactive Kanban board.
	•	Dragging a deal to “Won” triggered a confetti animation.
	•	Moving it to “Lost” caused the card to shake sadly.
	•	Everything worked seamlessly without additional adjustments.

⸻

3. Spider-Man Side-Scroller Game

To test its handling of physics and gameplay logic:

“Build a 2D Spider-Man side-scroller.”

GPT-5 delivered:
	•	Realistic web-swinging mechanics between buildings.
	•	Support for custom sprite uploads with automatic background removal.
	•	Instant bug fixes upon request.
	•	Smooth, engaging gameplay.

⸻

4. Marvel-Themed Tetris

A more playful request followed:

“Make a Tetris game with Marvel characters.”

The model created a fully playable Tetris clone:
	•	Character-themed pieces.
	•	Marvel-inspired emojis.
	•	Working line-clearing logic and controls.

⸻

5. Instant Website Creation

The prompts included:
	•	“Make a fancy website for Batman with shiny CSS.”
	•	“Build a modern site for a coding company using external images.”

GPT-5 produced visually appealing designs with:
	•	Clean layouts and polished styling.
	•	Project timelines and client engagement forms.
	•	Even better results when external images were allowed.

⸻

6. Writing with Insight

To test its writing capabilities, the reviewer provided samples of personal scripts and requested:

“Write an essay on why intelligence is adaptability, not skill maxing.”

While GPT-5 did not directly mimic the style, the essay it produced was:
	•	Rich in analogies and fresh perspectives.
	•	Focused on adaptability as the key to thriving in fast-changing environments.
	•	Non-generic and context-aware.

⸻

7. Game Concept – Sudarshan Chakra

Prompt:

“Design a game where the player uses a sudarshan chakra (frisbee weapon) with a skill tree.”

GPT-5 outlined a sophisticated system including:
	•	Throw mastery, path curvature, ricochets, and heat management.
	•	Mini-games for catching and teleporting the weapon.
	•	Ideas comparable to those from seasoned game designers.

⸻

8. Agent Mode – Limitations

When tasked with:

“Edit a video of today’s top news.”

The output was limited:
	•	Compiled generic B-roll with basic transitions.
	•	Lacked deep integration with professional editing tools.
	•	Clear strength remained in code and logic generation rather than fully autonomous multimedia production.

⸻

9. Deep Research Capabilities

Prompt:

“List 20 philosophical insights agreed upon by major books.”

The model generated:
	•	A nuanced, culturally diverse list of insights.
	•	Accurate niche data, such as startup costs for restaurants or pricing for private jets, presented with context.

⸻

Conclusion – Adaptability Above All

The hands-on testing made one thing clear: GPT-5 represents a major leap in automation, creativity, and reasoning.
	•	It can produce applications, games, written content, and research outputs from simple natural language prompts.
	•	The key takeaway is that adaptability now outweighs any single fixed skill.
	•	In an accelerating technological landscape, those who embrace change and pivot quickly will thrive, while rigid skill sets risk becoming obsolete.

Change is the only constant — and GPT-5 just turned up the pace.
""")

# %%
print(script)
# Out:
# OpenAIs GPT-5 is here! We put it to the test for truly automated software creation. From early access, we challenged it with app building, games, and deep research. It generated a fully functional Twitter clone, front-end and back-end, in moments, feeling like orchestrating a tireless dev team. It built a 2D Spider-Man side-scroller with realistic web-swinging and instant bug fixes. Beyond code, GPT-5 produced insightful essays, complex game concepts, and conducted nuanced, accurate research, even on niche topics. While not yet perfect for full video editing, this is a massive leap in automation, creativity, and reasoning. The takeaway is clear: adaptability now outweighs fixed skills. In our fast-changing world, those who embrace change will thrive. GPT-5 just turned up the pace.

# %%
from videoGenerator import VideoGenerator

generator = VideoGenerator()

text = "OpenAIs GPT-5 is here! We put it to the test for truly automated software creation. From early access, we challenged it with app building, games, and deep research. It generated a fully functional Twitter clone, front-end and back-end, in moments, feeling like orchestrating a tireless dev team. It built a 2D Spider-Man side-scroller with realistic web-swinging and instant bug fixes. Beyond code, GPT-5 produced insightful essays, complex game concepts, and conducted nuanced, accurate research, even on niche topics. While not yet perfect for full video editing, this is a massive leap in automation, creativity, and reasoning. The takeaway is clear: adaptability now outweighs fixed skills. In our fast-changing world, those who embrace change will thrive. GPT-5 just turned up the pace."

generator.create_video(text, "gpt-5")
# Out:
# Attempting to load background video from: /Users/smehta091/projects/butler/butler-core/bgvids/video720.mp4
# Successfully loaded background video
# Starting video at 596.43s and playing for 53.04s
# MoviePy - Building video /Users/smehta091/projects/butler/butler-core/outputs/gpt-5/gpt-5.mp4.
# MoviePy - Writing audio in gpt-5TEMP_MPY_wvf_snd.mp4
# MoviePy - Done.
# MoviePy - Writing video /Users/smehta091/projects/butler/butler-core/outputs/gpt-5/gpt-5.mp4
# MoviePy - Done !
# MoviePy - video ready /Users/smehta091/projects/butler/butler-core/outputs/gpt-5/gpt-5.mp4
# '/Users/smehta091/projects/butler/butler-core/outputs/gpt-5'
